# %%
# !git clone https://github.com/ahmed-h-elsheikh/polychaos-learn
# Out:
# fatal: destination path 'polychaos-learn' already exists and is not an empty directory.

# %%
# polychaos: deg -->, until mem brake
# 5, 10k - same
# hermite phys, prob (x, t - legendre)

# %%
# generate normal (uniform[-1, 1])features --> input model --> polycahos input = (x, t)
# normal (hermite prob) perm

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('seaborn')

import random
import time

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import MultiTaskElasticNetCV
from sklearn.preprocessing import StandardScaler

from pclearn import OrthogonalPolynomialsFeatures
from diffusion_equation import compute_solution
import torch

# %%
# # configuration of simulator
# # and parametrs of reservouir
# pwat = 2.0
# poil = 4.0
# vr = 0.3
# kwat = 1.0
# koil = 0.3


# pmin = 0.0
# pmax = 1.0
# nx0 = 50
# nx1 = 30
# nx2 = 1
# dx0 = 1.0 / nx0
# dx1 = 1.0 / nx1
# dx2 = 1.0 / nx2
# dt = 3.0 / 100
# niter = 100

# poro = 0.1 + np.zeros((nx0, nx1, nx2))
# perm = np.ones((nx0, nx1, nx2))


# configuration of simulator
# and parametrs of reservouir
perm = np.load('perm.npy')
nx0, nx1 = perm.shape
nx2 = 1
perm = np.reshape(perm, (nx0, nx1, nx2))
poro = 0.1 + np.zeros((nx0, nx1, nx2))

dx0 = 1.0 / nx0
dx1 = 1.0 / nx1
dx2 = 1.0 / nx2

pwat = 2.0
poil = 4.0
vr = 0.3
kwat = 1.0
koil = 0.3

pmin = 0.0
pmax = 1.0

niter = 5000
t_final = 3.0
dt = t_final / niter

# %%
# # configuration of simulator
# # and parametrs of reservouir
# perm = np.load('/Users/kirill/edu/3course/PINN_project/TwoPhase2/perm.npy')
# nx0, nx1 = perm.shape
# nx2 = 1
# perm = np.reshape(perm, (nx0, nx1, nx2))
# poro = 0.1 + np.zeros((nx0, nx1, nx2))

# dx0 = 1.0 / nx0
# dx1 = 1.0 / nx1
# dx2 = 1.0 / nx2

# pwat = 2.0
# poil = 4.0
# vr = 0.3
# kwat = 1.0
# koil = 0.3

# pmin = 0.0
# pmax = 1.0

# niter = 5000
# t_final = 3.0
# dt = t_final / niter

# %%
# 2000
# sim_data = np.loadtxt("2000_data/sim_2k.txt", dtype=np.float32)
# x_list = np.loadtxt("2000_data/x_2k.txt", dtype=np.float32)
# y_list = np.loadtxt("2000_data/y_2k.txt", dtype=np.float32)
# t_list = np.loadtxt("2000_data/t_2k.txt", dtype=np.float32)
# sim_data, x_list, y_list, t_list

# %%
# # 5000 3sigma
# sim_data = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k_3sigma/sim_5000.txt", dtype=np.float32)
# x_list = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k_3sigma/x_5000.txt", dtype=np.float32)
# y_list = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k_3sigma/y_5000.txt", dtype=np.float32)
# t_list = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k_3sigma/t_5000.txt", dtype=np.float32)
# sim_data, x_list, y_list, t_list

# %%
# # 5000
# sim_data_old = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k/sim_5000.txt", dtype=np.float32)
# x_list_old = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k/x_5000.txt", dtype=np.float32)
# y_list_old = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k/y_5000.txt", dtype=np.float32)
# t_list_old = np.loadtxt("/Users/kirill/edu/3course/PINN_project/TwoPhase2/data_5k/t_5000.txt", dtype=np.float32)
# sim_data_old, x_list_old, y_list_old, t_list_old


# 5000
n_points = 500
rand_points = np.random.randint(0, 5000, n_points)

# 5000
sim_data = np.loadtxt("data_5k_200225/sim_5000.txt", dtype=np.float32)[rand_points]
x_list = np.loadtxt("data_5k_200225/x_5000.txt", dtype=np.float32)[rand_points]
y_list = np.loadtxt("data_5k_200225/y_5000.txt", dtype=np.float32)[rand_points]
t_list = np.loadtxt("data_5k_200225/t_5000.txt", dtype=np.float32)[rand_points]

# %%
dx0 = 1.0 / nx0
dx1 = 1.0 / nx1
dx2 = 1.0 / nx2


# pwat1 = 2.0 * torch.ones_like(x).requires_grad_(True)
# poil1 = 4.0 * torch.ones_like(x).requires_grad_(True)
# kwat1 = 1.0 * torch.ones_like(x).requires_grad_(True)
# koil1 = 0.3 * torch.ones_like(x).requires_grad_(True)

# points = torch.stack((t, x, y), -1).requires_grad_(True)
points = np.stack((t_list * dt, x_list * dx0, y_list * dx1), -1)
# points_old = np.stack((t_list_old * dt, x_list_old * dx0, y_list_old * dx1), -1)
points, sim_data
# Out:
# (array([[1.3746    , 0.15625   , 0.859375  ],
#         [0.90540004, 0.140625  , 0.1875    ],
#         [0.1194    , 0.53125   , 0.625     ],
#         ...,
#         [1.5912001 , 0.15625   , 0.625     ],
#         [2.8656    , 0.15625   , 0.0625    ],
#         [0.54300004, 0.515625  , 0.296875  ]], dtype=float32),
#  array([[ 8.9297980e-01,  1.1986325e-33,  1.0000000e+00],
#         [ 9.1411865e-01, -4.1632336e-35,  1.0000000e+00],
#         [ 5.3118581e-01,  7.5421187e-35,  1.0000000e+00],
#         ...,
#         [ 8.6796302e-01,  1.0314495e-01,  8.9685506e-01],
#         [ 8.6017907e-01,  1.2276773e-08,  1.0000000e+00],
#         [ 4.3971401e-01,  4.2738036e-35,  1.0000000e+00]], dtype=float32))

# %%
perm = np.load('perm.npy')
nx0, nx1 = perm.shape
nx2 = 1
perm = np.reshape(perm, (nx0, nx1, nx2))
poro = 0.1 + np.zeros((nx0, nx1, nx2))

dx0 = 1.0 / nx0
dx1 = 1.0 / nx1
dx2 = 1.0 / nx2

pwat = 2.0
poil = 4.0
vr = 0.3
kwat = 1.0
koil = 0.3

pmin = 0.0
pmax = 1.0
dt = 0.26e-1
niter = 100

# poro = 0.1 + np.zeros((nx0, nx1, nx2))
# perm = np.ones((nx0, nx1, nx2))

pres, swat, soil = compute_solution(perm, poro,
                                    dx0, dx1, dx2, dt * niter, niter,
                                    pwat, kwat, poil, koil, vr,
                                    pmin=0.0, pmax=1.0)

# %%
def fix_random_seed(seed_):
    random.seed(seed_)
    np.random.seed(seed_)

# %%
norm = StandardScaler()
norm.fit_transform(points)
# Out:
# array([[-0.22636825, -1.2115364 ,  1.3353997 ],
#        [-0.77706033, -1.2651727 , -1.0235761 ],
#        [-1.6995752 ,  0.07573444,  0.51250124],
#        ...,
#        [ 0.02785154, -1.2115364 ,  0.51250124],
#        [ 1.5235931 , -1.2115364 , -1.4624554 ],
#        [-1.2024031 ,  0.02209815, -0.63955677]], dtype=float32)

# %%
rand_seed_ = random.randint(1, 10000)  # random.randint(1, 10000)  # fix seed randomly
fix_random_seed(rand_seed_)


# load data set
# X_train, X_test, y_train, y_test = train_test_split(points, sim_data, test_size=0.3, random_state=rand_seed_)
# # X_train_old, X_test_old, y_train_old, y_test_old = train_test_split(points_old, sim_data_old, 
# #                                                                     test_size=0.3, random_state=rand_seed_)

n_samples_train, n_features = points.shape

print('Working on training data of size {}'.format(points.shape[0]))
print('Number of features {}'.format(points.shape[1]))
# Out:
# Working on training data of size 500
# Number of features 3

# %%
# define solver parameters
tol_eps = 1.0e-6  # tolerance
n_cv_folds = 5
alphas = np.logspace(-5, 1, 5)
l1_ratio = np.linspace(0.05, 0.95, 15)
n_max_iter = 500  # number of iteratons

fitting_method = MultiTaskElasticNetCV(l1_ratio=l1_ratio, alphas=alphas,
                              max_iter=n_max_iter, tol=tol_eps, cv=n_cv_folds,
                              fit_intercept=False, selection='random')

# define interpolation parameters
poly_degree = 25  # degree of polynomial

# hermite
# input normal ---> std scale
# u[-1, 1] legendre, expon laguerre

poly_type = ['legendre'] * n_features  # could be different e.g. ['legendre', 'hermite']

reduction = False # ok
dlist = []
truncated_dim = 20
single_iter_dim = 15
niter = 500
nrand = 50

t_start = time.time()
orthopoly = OrthogonalPolynomialsFeatures(
    degree=poly_degree, dlist=dlist, poly_type=poly_type,
    reduction=reduction, basis_dim=truncated_dim,
    single_iter_dim=single_iter_dim, niter=niter, nrand=nrand,
    clf=fitting_method)
print('Calling OrthogonalPolynomialsFeatures in {:6f} seconds'.format(time.time() - t_start))

regression_pipeline = Pipeline(steps=[
    ('orthopoly', orthopoly),
    ('fitting_method', fitting_method)])

t_start = time.time()
regression_pipeline.fit(norm.transform(points), sim_data)
print('Linear problem (with PCE basis) has been solved in {:6f} seconds'.format(time.time() - t_start))

t_start = time.time()
y_train_pred = regression_pipeline.predict(norm.transform(points))
print('Prediction over the training data in {:6f} seconds'.format(time.time() - t_start))

# t_start = time.time()
# y_test_pred = regression_pipeline.predict(X_test)
# print('Prediction over the test data in {:6f} seconds'.format(time.time() - t_start))

mse_train = mean_squared_error(sim_data, y_train_pred)
# mse_test = mean_squared_error(y_test, y_test_pred)

print('MSE train: {}'.format(mse_train))

# %%
# define solver parameters
tol_eps = 1.0e-6  # tolerance
n_cv_folds = 5
alphas = np.logspace(-5, 1, 5)
l1_ratio = np.linspace(0.05, 0.95, 15)
n_max_iter = 500  # number of iteratons

fitting_method = MultiTaskElasticNetCV(l1_ratio=l1_ratio, alphas=alphas,
                              max_iter=n_max_iter, tol=tol_eps, cv=n_cv_folds,
                              fit_intercept=False, selection='random')

# define interpolation parameters
poly_degree = 25  # degree of polynomial

# hermite
# input normal ---> std scale
# u[-1, 1] legendre, expon laguerre

poly_type = ['legendre'] * n_features  # could be different e.g. ['legendre', 'hermite']

reduction = False # ok
dlist = []
truncated_dim = 20
single_iter_dim = 15
niter = 500
nrand = 50

t_start = time.time()
orthopoly = OrthogonalPolynomialsFeatures(
    degree=poly_degree, dlist=dlist, poly_type=poly_type,
    reduction=reduction, basis_dim=truncated_dim,
    single_iter_dim=single_iter_dim, niter=niter, nrand=nrand,
    clf=fitting_method)
print('Calling OrthogonalPolynomialsFeatures in {:6f} seconds'.format(time.time() - t_start))

regression_pipeline = Pipeline(steps=[
    ('orthopoly', orthopoly),
    ('fitting_method', fitting_method)])

t_start = time.time()
regression_pipeline.fit(norm.transform(points), sim_data)
print('Linear problem (with PCE basis) has been solved in {:6f} seconds'.format(time.time() - t_start))

t_start = time.time()
y_train_pred = regression_pipeline.predict(norm.transform(points))
print('Prediction over the training data in {:6f} seconds'.format(time.time() - t_start))

# t_start = time.time()
# y_test_pred = regression_pipeline.predict(X_test)
# print('Prediction over the test data in {:6f} seconds'.format(time.time() - t_start))

mse_train = mean_squared_error(sim_data, y_train_pred)
# mse_test = mean_squared_error(y_test, y_test_pred)

print('MSE train: {}'.format(mse_train))
# Out:
# Calling OrthogonalPolynomialsFeatures in 0.000105 seconds
# n_output_features: 3276
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.69500732421875, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.97236633300781, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.24809193611145, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2574774920940399, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12551096081733704, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99.87479400634766, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.65818405151367, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.276893138885498, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2601599097251892, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12458200752735138, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107.07426452636719, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.84476089477539, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.252706289291382, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2437700778245926, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10917247831821442, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101.0045166015625, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.4733772277832, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2477381229400635, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23010070621967316, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10104094445705414, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.58419036865234, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.10819625854492, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.290895700454712, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26885494589805603, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12883272767066956, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.38862609863281, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.705810546875, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.568307876586914, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26733526587486267, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12162034213542938, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106.29743194580078, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.860137939453125, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5899696350097656, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27539968490600586, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12621784210205078, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.29216003417969, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.72083282470703, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.576749801635742, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26232054829597473, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11127970367670059, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107.39205169677734, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.03443145751953, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5947418212890625, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25957655906677246, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11292875558137894, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.08342742919922, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.68927764892578, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6041996479034424, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27617794275283813, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12658032774925232, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.80021667480469, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.727516174316406, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8721461296081543, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28562650084495544, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12501715123653412, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.23545837402344, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.62505340576172, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9265222549438477, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3120194673538208, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14290809631347656, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.71073150634766, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.80492401123047, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8770387172698975, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2867851257324219, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11796025931835175, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.4131851196289, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.88538360595703, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9461703300476074, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2984136939048767, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13018657267093658, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112.41767883300781, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.532012939453125, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9470653533935547, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3089713156223297, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13995249569416046, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117.21966552734375, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.92422103881836, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.182173252105713, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31322962045669556, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13499952852725983, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112.74553680419922, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.63848876953125, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.211516380310059, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32996895909309387, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14568206667900085, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.07228088378906, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60.1614990234375, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.141735553741455, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30345669388771057, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.119602270424366, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.87936401367188, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.00553512573242, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.2430500984191895, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32398709654808044, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13821858167648315, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.00116729736328, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.71601486206055, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.218322277069092, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3216616213321686, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13975360989570618, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120.3187484741211, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.804725646972656, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.46266508102417, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3352425694465637, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14118604362010956, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.63153839111328, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.31159973144531, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.489233493804932, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34992358088493347, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15126453340053558, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123.196044921875, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.10977935791016, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.380255699157715, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31485632061958313, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11792344599962234, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.96448516845703, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.78584671020508, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.543943405151367, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3511965870857239, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14738309383392334, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.1507339477539, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.449649810791016, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.470463275909424, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3368259370326996, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14120428264141083, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123.00115966796875, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.2296371459961, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.719834804534912, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3484683632850647, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14185108244419098, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118.22681427001953, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.78324127197266, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.740524768829346, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3597220778465271, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14925937354564667, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.49942016601562, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67.6365966796875, tolerance: 0.0005165504408068955
# ...
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.560440540313721, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43372321128845215, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13863466680049896, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130.97996520996094, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.398193359375, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.378629207611084, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4164564907550812, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1182183250784874, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.28734588623047, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89.57850646972656, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.639970302581787, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4522664248943329, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14364832639694214, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126.43470001220703, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.92481994628906, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.537158489227295, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43946608901023865, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1373341977596283, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128.78582763671875, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.74958801269531, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.712046146392822, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4338352382183075, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1317797303199768, tolerance: 0.0005129469209350646
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124.20389556884766, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.16191864013672, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.80746603012085, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4461463391780853, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13899800181388855, tolerance: 0.0005119226407259703
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131.15478515625, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95.83391571044922, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.626498699188232, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4333322048187256, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12195111066102982, tolerance: 0.0005165504408068955
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.80952453613281, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.8191909790039, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.8712992668151855, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.46414878964424133, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14416180551052094, tolerance: 0.0005141990841366351
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126.93380737304688, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.29219818115234, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.782212257385254, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.45586061477661133, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:673: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14058342576026917, tolerance: 0.0005113357328809798
#   model = cd_fast.enet_coordinate_descent_multi_task(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:2637: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.39723205566406, tolerance: 0.0006417387630790472
#   ) = cd_fast.enet_coordinate_descent_multi_task(
# Linear problem (with PCE basis) has been solved in 373.337207 seconds
# Prediction over the training data in 0.535426 seconds
# MSE train: 0.1704617589712143
# array([[ 0.8200547 ,  0.0145729 ,  0.96269375],
#        [ 0.63119495, -0.01431808,  1.0118324 ],
#        [ 0.01428743,  0.0089594 ,  0.9897329 ],
#        ...,
#        [ 0.06114641, -0.00118552,  0.97959924],
#        [ 0.23257953, -0.00407927,  1.014801  ],
#        [ 0.35402694, -0.00408072,  1.0009662 ]], dtype=float32)

# %%
perm = np.load('perm.npy')
nx0, nx1 = perm.shape
nx2 = 1
perm = np.reshape(perm, (nx0, nx1, nx2))
poro = 0.1 + np.zeros((nx0, nx1, nx2))

dx0 = 1.0 / nx0
dx1 = 1.0 / nx1
dx2 = 1.0 / nx2

pwat = 2.0
poil = 4.0
vr = 0.3
kwat = 1.0
koil = 0.3

pmin = 0.0
pmax = 1.0
dt = 0.26e-1
niter = 100

# pres, swat, soil = compute_solution(perm, poro,
#                                     dx0, dx1, dx2, dt * niter, niter,
#                                     pwat, kwat, poil, koil, vr,
#                                     pmin=0.0, pmax=1.0)

time_for_model = (niter * dt) * np.ones(64 * 64)
x_for_model = dx0 * torch.arange(64)
y_for_model = dx1 * torch.arange(64)
#     cartesian_points = np.transpose([np.tile(x_for_model, len(y_for_model)), 
#                                      np.repeat(y_for_model, len(x_for_model))])
cartesian_points = torch.cartesian_prod(x_for_model, y_for_model)
cartesian_points = cartesian_points.detach().numpy()
pred_points = np.stack((time_for_model, cartesian_points[:, 0], cartesian_points[:, 1]), -1)
# norm.fit_transform(points)
model_prediction = regression_pipeline.predict(norm.fit_transform(pred_points))


plt.figure()
plt.title('Давление, симулятор')
plt.imshow(pres[:, :, :, -1])
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('color_pres_sim.png')
plt.show()

plt.figure()
plt.title('Pressure, PCE')
plt.imshow(model_prediction[:, 0].reshape(nx0, nx1, nx2))
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('color_pce_pres.png')
plt.show()



plt.figure()
plt.title('Water saturation, sim')
plt.imshow(swat[:, :, :, -1])
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

plt.figure()
plt.title('Water saturation, PCE')
plt.imshow(model_prediction[:, 1].reshape(nx0, nx1, nx2))
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('color_pce_swat.png')
plt.show()



plt.figure()
plt.title('Давление симулятор')
plt.scatter(np.linspace(0.0, 1.0, nx0), pres[:, 0, 0, 3], label='Симулятор')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
norm.transform(np.stack((time_for_model, cartesian_points[:, 0], cartesian_points[:, 1]), -1))
# Out:
# array([[98.72150703, -1.77436058, -1.64609357],
#        [98.72150703, -1.77436058, -1.52922502],
#        [98.72150703, -1.77436058, -1.41235647],
#        ...,
#        [98.72150703,  1.6730489 ,  1.50935732],
#        [98.72150703,  1.6730489 ,  1.62622596],
#        [98.72150703,  1.6730489 ,  1.7430944 ]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd

# %%
model_pred_train.shape
# Out:
# (500, 3)

# %%
model_pred_train = regression_pipeline.predict(points)

# %%
satur = [mean_squared_error(sim_data[:, 1], model_pred_train[:, 1]),
         mean_absolute_error(sim_data[:, 1], model_pred_train[:, 1]),
         r2_score(sim_data[:, 1], model_pred_train[:, 1]),
         np.sqrt(mean_squared_error(sim_data[:, 1], model_pred_train[:, 1]))]

pres_train = [mean_squared_error(sim_data[:, 0], model_pred_train[:, 0]),
         mean_absolute_error(sim_data[:, 0], model_pred_train[:, 0]),
         r2_score(sim_data[:, 0], model_pred_train[:, 0]),
         np.sqrt(mean_squared_error(sim_data[:, 0], model_pred_train[:, 0]))]

# %%
metrics_train = pd.DataFrame({'Saturation': satur, 'Pressure': pres_train}, index=['MSE', 'MAE', 'R^2', 'RMSE'])

# %%
metrics_train
# Out:
#       Saturation  Pressure
# MSE     0.002245  0.002057
# MAE     0.022651  0.028261
# R^2     0.741827  0.982704
# RMSE    0.047379  0.045353
